# %%
##import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = 6*np.random.rand(100,1)-3
y= 0.5*x**2 + x + 2 + np.random.randn(100,1)
## use only audartic ewuation

# %%
## plot this above one 

plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train,regression.predict(x_train),color='red')
plt.scatter(x_train,y_train,color='blue')

# %%
## polynomial regression

from sklearn.preprocessing import PolynomialFeatures

# %%
ploy = PolynomialFeatures(degree=2,include_bias=True)
x_poly = ploy.fit_transform(x_train)
x_test = ploy.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 ploy = PolynomialFeatures(degree=2,include_bias=True)
#       2 x_poly = ploy.fit_transform(x_train)
# ----> 3 x_test = ploy.transform(x_test)
#
# File c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages\sklearn\preprocessing\_polynomial.py:425, in PolynomialFeatures.transform(self, X)
#     423 check_is_fitted(self)
#     424 xp, _, device_ = get_namespace_and_device(X)
# --> 425 X = validate_data(
#     426     self,
#     427     X,
#     428     order="F",
#     429     dtype=supported_float_dtypes(xp=xp, device=device_),
#     430     reset=False,
#     431     accept_sparse=("csr", "csc"),
#     432 )
#     434 n_samples, n_features = X.shape
#     435 max_int32 = xp.iinfo(xp.int32).max
#
# File c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages\sklearn\utils\validation.py:3059, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
# -> 3059     _check_n_features(_estimator, X, reset=reset)
#    3061 return out
#
# File c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages\sklearn\utils\validation.py:2923, in _check_n_features(estimator, X, reset)
#    2920     return
#    2922 if n_features != estimator.n_features_in_:
# -> 2923     raise ValueError(
#    2924         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2925         f"is expecting {estimator.n_features_in_} features as input."
#    2926     )
#
# ValueError: X has 3 features, but PolynomialFeatures is expecting 1 features as input.

# %%
x_poly
# Out:
# array([[ 1.00000000e+00,  1.66765033e+00,  2.78105762e+00],
#        [ 1.00000000e+00,  1.27935937e+00,  1.63676040e+00],
#        [ 1.00000000e+00, -4.81043936e-01,  2.31403268e-01],
#        [ 1.00000000e+00,  2.37345172e+00,  5.63327305e+00],
#        [ 1.00000000e+00, -6.07465963e-01,  3.69014896e-01],
#        [ 1.00000000e+00,  2.33846391e+00,  5.46841346e+00],
#        [ 1.00000000e+00,  8.61769392e-01,  7.42646485e-01],
#        [ 1.00000000e+00, -2.85490298e+00,  8.15047103e+00],
#        [ 1.00000000e+00, -1.56925251e+00,  2.46255345e+00],
#        [ 1.00000000e+00, -1.26709730e+00,  1.60553557e+00],
#        [ 1.00000000e+00,  1.55780118e+00,  2.42674453e+00],
#        [ 1.00000000e+00, -5.47014947e-01,  2.99225353e-01],
#        [ 1.00000000e+00, -9.35895754e-01,  8.75900862e-01],
#        [ 1.00000000e+00,  1.99814916e+00,  3.99260008e+00],
#        [ 1.00000000e+00, -6.15204441e-01,  3.78476504e-01],
#        [ 1.00000000e+00, -1.24971609e+00,  1.56179031e+00],
#        [ 1.00000000e+00,  1.90599631e-01,  3.63282195e-02],
#        [ 1.00000000e+00,  2.74710939e+00,  7.54661000e+00],
#        [ 1.00000000e+00, -2.89009903e+00,  8.35267238e+00],
#        [ 1.00000000e+00,  1.78430509e+00,  3.18374464e+00],
#        [ 1.00000000e+00,  1.37779788e+00,  1.89832701e+00],
#        [ 1.00000000e+00,  2.83128699e+00,  8.01618600e+00],
#        [ 1.00000000e+00, -2.69137760e+00,  7.24351341e+00],
#        [ 1.00000000e+00, -2.05148784e+00,  4.20860235e+00],
#        [ 1.00000000e+00,  1.06393933e+00,  1.13196691e+00],
#        [ 1.00000000e+00, -1.64089574e+00,  2.69253883e+00],
#        [ 1.00000000e+00, -2.78217795e+00,  7.74051417e+00],
#        [ 1.00000000e+00, -2.71598558e+00,  7.37657770e+00],
#        [ 1.00000000e+00, -6.62492852e-01,  4.38896779e-01],
#        [ 1.00000000e+00,  2.46879190e+00,  6.09493342e+00],
#        [ 1.00000000e+00, -6.31099876e-01,  3.98287053e-01],
#        [ 1.00000000e+00,  1.17126415e+00,  1.37185970e+00],
#        [ 1.00000000e+00,  2.81406394e+00,  7.91895586e+00],
#        [ 1.00000000e+00,  2.23294748e+00,  4.98605446e+00]])

# %%
x_test
# Out:
# array([[ 1.        , -2.42869326,  5.89855093],
#        [ 1.        , -0.53515906,  0.28639522],
#        [ 1.        ,  2.21668101,  4.91367469],
#        [ 1.        , -1.72359354,  2.9707747 ],
#        [ 1.        ,  1.26187991,  1.5923409 ],
#        [ 1.        ,  2.06467674,  4.26289005],
#        [ 1.        , -0.4785231 ,  0.22898436],
#        [ 1.        , -0.76733774,  0.58880721],
#        [ 1.        ,  0.44748418,  0.20024209],
#        [ 1.        ,  1.28910986,  1.66180424],
#        [ 1.        ,  1.51186444,  2.28573408],
#        [ 1.        ,  1.15678162,  1.33814371],
#        [ 1.        ,  1.88854026,  3.56658431],
#        [ 1.        ,  0.16088229,  0.02588311],
#        [ 1.        , -2.42297459,  5.87080588],
#        [ 1.        ,  2.39228115,  5.72300911],
#        [ 1.        , -1.26299917,  1.59516691],
#        [ 1.        , -0.10294094,  0.01059684],
#        [ 1.        ,  0.98285065,  0.9659954 ],
#        [ 1.        , -1.00778262,  1.0156258 ],
#        [ 1.        ,  2.62084691,  6.86883852],
#        [ 1.        ,  0.5648849 ,  0.31909495],
#        [ 1.        , -1.1287413 ,  1.27405691],
#        [ 1.        , -0.88339898,  0.78039376],
#        [ 1.        , -1.62371028,  2.63643508]])

# %%
regression.fit(x_poly,y_train)
y_pred = regression.predict(x_test)

# %%
plt.scatter(x_train,regression.predict(x_poly),color='red')
plt.scatter(x_train,y_train,color='blue')

# %%
ploy = PolynomialFeatures(degree=3,include_bias=True)
x_train_poly = ploy.fit_transform(x_train)
x_test_poly = ploy.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 ploy = PolynomialFeatures(degree=3,include_bias=True)
#       2 x_train_poly = ploy.fit_transform(x_train)
# ----> 3 x_test_poly = ploy.transform(x_test)
#
# File c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages\sklearn\preprocessing\_polynomial.py:425, in PolynomialFeatures.transform(self, X)
#     423 check_is_fitted(self)
#     424 xp, _, device_ = get_namespace_and_device(X)
# --> 425 X = validate_data(
#     426     self,
#     427     X,
#     428     order="F",
#     429     dtype=supported_float_dtypes(xp=xp, device=device_),
#     430     reset=False,
#     431     accept_sparse=("csr", "csc"),
#     432 )
#     434 n_samples, n_features = X.shape
#     435 max_int32 = xp.iinfo(xp.int32).max
#
# File c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages\sklearn\utils\validation.py:3059, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
# -> 3059     _check_n_features(_estimator, X, reset=reset)
#    3061 return out
#
# File c:\Users\saiki\OneDrive\Desktop\Nagraju annaya\telugupython\Lib\site-packages\sklearn\utils\validation.py:2923, in _check_n_features(estimator, X, reset)
#    2920     return
#    2922 if n_features != estimator.n_features_in_:
# -> 2923     raise ValueError(
#    2924         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2925         f"is expecting {estimator.n_features_in_} features as input."
#    2926     )
#
# ValueError: X has 3 features, but PolynomialFeatures is expecting 1 features as input.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
